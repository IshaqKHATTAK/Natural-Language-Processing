# %% [markdown]
# <a href="https://colab.research.google.com/github/IshaqKHATTAK/Natural-Language-Processing/blob/main/lab4_nlp_n_gram_%26_POS_taging_from_scrach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import movie_reviews

# %%
from nltk import pos_tag

# %%
cor = '''Before we move on to the probability stuff, let’s answer this question first. Why is it that we need to learn 
n-gram and the related probability? Well, in Natural Language Processing, or NLP for short, n-grams are used for a 
variety of things. Some examples include auto completion of sentences (such as the one we see in Gmail these days), 
auto spell check (yes, we can do that as well), and to a certain extent, we can check for grammar in a given 
sentence. We’ll see some examples of this later in the post when we talk about assigning probabilities to n-grams.
'''

# %%
sent = cor.split('.')

# %%
len(sent)
# Out:
# 5

# %%
def n_grams(cor,ngram=1):
  words=[word for word in cor.split(" ")]  
#  print("Sentence after removing stopwords:",words)

  temp=zip(*[words[i:] for i in range(0,ngram)])
    
  ans=[' '.join(ngram) for ngram in temp]
  return ans

# %%
word= n_grams(cor,2)

# %%
word
# Out:
# ['Before we',
#  'we move',
#  'move on',
#  'on to',
#  'to the',
#  'the probability',
#  'probability stuff,',
#  'stuff, let’s',
#  'let’s answer',
#  'answer this',
#  'this question',
#  'question first.',
#  'first. Why',
#  'Why is',
#  'is it',
#  'it that',
#  'that we',
#  'we need',
#  'need to',
#  'to learn',
#  'learn \nn-gram',
#  '\nn-gram and',
#  'and the',
#  'the related',
#  'related probability?',
#  'probability? Well,',
#  'Well, in',
#  'in Natural',
#  'Natural Language',
#  'Language Processing,',
#  'Processing, or',
#  'or NLP',
#  'NLP for',
#  'for short,',
#  'short, n-grams',
#  'n-grams are',
#  'are used',
#  'used for',
#  'for a',
#  'a \nvariety',
#  '\nvariety of',
#  'of things.',
#  'things. Some',
#  'Some examples',
#  'examples include',
#  'include auto',
#  'auto completion',
#  'completion of',
#  'of sentences',
#  'sentences (such',
#  '(such as',
#  'as the',
#  'the one',
#  'one we',
#  'we see',
#  'see in',
#  'in Gmail',
# ...

# %%
tags = []
for wo in word:
    w1 = wo.split(" ")
    w2 = pos_tag(w1)
    for i in range(0,2):
        tags.append((w2[0][1],w2[1][1]))

# %%
print(tags)
# Out:
# [('IN', 'PRP'), ('IN', 'PRP'), ('PRP', 'VBP'), ('PRP', 'VBP'), ('NN', 'IN'), ('NN', 'IN'), ('IN', 'TO'), ('IN', 'TO'), ('TO', 'DT'), ('TO', 'DT'), ('DT', 'NN'), ('DT', 'NN'), ('NN', 'NN'), ('NN', 'NN'), ('NN', 'NN'), ('NN', 'NN'), ('NN', 'NN'), ('NN', 'NN'), ('NN', 'DT'), ('NN', 'DT'), ('DT', 'NN'), ('DT', 'NN'), ('NN', 'NN'), ('NN', 'NN'), ('NN', 'WRB'), ('NN', 'WRB'), ('WRB', 'VBZ'), ('WRB', 'VBZ'), ('VBZ', 'PRP'), ('VBZ', 'PRP'), ('PRP', 'IN'), ('PRP', 'IN'), ('IN', 'PRP'), ('IN', 'PRP'), ('PRP', 'VBP'), ('PRP', 'VBP'), ('NN', 'TO'), ('NN', 'TO'), ('TO', 'VB'), ('TO', 'VB'), ('JJ', 'NN'), ('JJ', 'NN'), ('NN', 'CC'), ('NN', 'CC'), ('CC', 'DT'), ('CC', 'DT'), ('DT', 'JJ'), ('DT', 'JJ'), ('JJ', 'NN'), ('JJ', 'NN'), ('NN', 'NNP'), ('NN', 'NNP'), ('NNP', 'IN'), ('NNP', 'IN'), ('IN', 'NNP'), ('IN', 'NNP'), ('JJ', 'NN'), ('JJ', 'NN'), ('NN', 'NN'), ('NN', 'NN'), ('NN', 'CC'), ('NN', 'CC'), ('CC', 'VB'), ('CC', 'VB'), ('NN', 'IN'), ('NN', 'IN'), ('IN', 'NN'), ('IN', 'NN'), ('JJ', 'NNS'), 
# ...

# %%
uniqu_tag = []
for tag in tags:
    if tag not in uniqu_tag:
        uniqu_tag.append(tag)

# %%
print(len(uniqu_tag ))
print(len(tags))
# Out:
# 50
# 202

# %%
cnt = [tags.count(un) for un in uniqu_tag]

cnt
# Out:
# [4,
#  8,
#  16,
#  2,
#  4,
#  12,
#  20,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  10,
#  6,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  8,
#  2,
#  4,
#  2,
#  2,
#  10,
#  4,
#  6,
#  2,
#  2,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2]

# %%
#uniqu_tag1 = uniqu_tag
uniqu_tag1 = []
for i in uniqu_tag:
    p=' '.join(i)
    uniqu_tag1.append(p)

# %%
import pandas as pd
from matplotlib import pyplot as plt


name = uniqu_tag1
price =cnt

# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(name, price)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
            str(round((i.get_width()), 2)),
            fontsize = 10, fontweight ='bold',
            color ='grey')

# Add Plot Title
ax.set_title('Sports car and their price in crore',
    loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
        color ='grey', ha ='right', va ='bottom',
        alpha = 0.7)

# Show Plot
plt.show()
# Out:
# /var/folders/4j/8jr16sgd1tx5t1bf18_0px5m0000gn/T/ipykernel_788/3099645457.py:27: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',

# %%
word1= n_grams(cor,3)

# %%
word1
# Out:
# ['Before we move',
#  'we move on',
#  'move on to',
#  'on to the',
#  'to the probability',
#  'the probability stuff,',
#  'probability stuff, let’s',
#  'stuff, let’s answer',
#  'let’s answer this',
#  'answer this question',
#  'this question first.',
#  'question first. Why',
#  'first. Why is',
#  'Why is it',
#  'is it that',
#  'it that we',
#  'that we need',
#  'we need to',
#  'need to learn',
#  'to learn \nn-gram',
#  'learn \nn-gram and',
#  '\nn-gram and the',
#  'and the related',
#  'the related probability?',
#  'related probability? Well,',
#  'probability? Well, in',
#  'Well, in Natural',
#  'in Natural Language',
#  'Natural Language Processing,',
#  'Language Processing, or',
#  'Processing, or NLP',
#  'or NLP for',
#  'NLP for short,',
#  'for short, n-grams',
#  'short, n-grams are',
#  'n-grams are used',
#  'are used for',
#  'used for a',
#  'for a \nvariety',
#  'a \nvariety of',
#  '\nvariety of things.',
#  'of things. Some',
# ...

# %%
tags = []
for wo in word1:
    w1 = wo.split(" ")
    w2 = pos_tag(w1)

    for i in range(0,2):
        tags.append((w2[0][1],w2[1][1],w2[2][1]))

# %%
tags
# Out:
# [('IN', 'PRP', 'VBP'),
#  ('IN', 'PRP', 'VBP'),
#  ('PRP', 'VBP', 'IN'),
#  ('PRP', 'VBP', 'IN'),
#  ('NN', 'IN', 'TO'),
#  ('NN', 'IN', 'TO'),
#  ('IN', 'TO', 'DT'),
#  ('IN', 'TO', 'DT'),
#  ('TO', 'DT', 'NN'),
#  ('TO', 'DT', 'NN'),
#  ('DT', 'NN', 'NN'),
#  ('DT', 'NN', 'NN'),
#  ('NN', 'NN', 'NN'),
#  ('NN', 'NN', 'NN'),
#  ('NN', 'NN', 'NN'),
#  ('NN', 'NN', 'NN'),
#  ('NN', 'NN', 'DT'),
#  ('NN', 'NN', 'DT'),
#  ('NN', 'DT', 'NN'),
#  ('NN', 'DT', 'NN'),
#  ('DT', 'NN', 'NN'),
#  ('DT', 'NN', 'NN'),
#  ('NN', 'NN', 'WRB'),
#  ('NN', 'NN', 'WRB'),
#  ('NN', 'WRB', 'VBZ'),
#  ('NN', 'WRB', 'VBZ'),
#  ('WRB', 'VBZ', 'PRP'),
#  ('WRB', 'VBZ', 'PRP'),
#  ('VBZ', 'PRP', 'IN'),
#  ('VBZ', 'PRP', 'IN'),
#  ('PRP', 'IN', 'PRP'),
#  ('PRP', 'IN', 'PRP'),
#  ('IN', 'PRP', 'VBP'),
#  ('IN', 'PRP', 'VBP'),
#  ('PRP', 'VBP', 'TO'),
#  ('PRP', 'VBP', 'TO'),
#  ('NN', 'TO', 'VB'),
#  ('NN', 'TO', 'VB'),
#  ('TO', 'VB', 'JJ'),
#  ('TO', 'VB', 'JJ'),
#  ('JJ', 'CD', 'CC'),
# ...

# %%
cnt = [tags.count(un) for un in uniqu_tag]

# %%
uniqu_tag = []
for tag in tags:
    if tag not in uniqu_tag:
        uniqu_tag.append(tag)

# %%
uniqu_tag1 = []
for i in uniqu_tag:
    p=' '.join(i)
    uniqu_tag1.append(p)

# %%
import pandas as pd
from matplotlib import pyplot as plt


name = uniqu_tag1
price =cnt

# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(name, price)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
            str(round((i.get_width()), 2)),
            fontsize = 10, fontweight ='bold',
            color ='grey')

# Add Plot Title
ax.set_title('Sports car and their price in crore',
    loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 20,
        color ='grey', ha ='right', va ='bottom',
        alpha = 0.7)

# Show Plot
plt.show()
# Out:
# /var/folders/4j/8jr16sgd1tx5t1bf18_0px5m0000gn/T/ipykernel_788/3371024106.py:27: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',

# %%
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import brown

# Load the shakespeare



# Generate N-grams, bi-grams and tri-grams using our code
tokens = n_grams(cor,2)
#n_grams = [tuple(tokens[i:i+n]) for n in range(1,4) for i in range(len(tokens)-n+1)]
#n_gram_counts = Counter(n_grams)

# Generate N-grams using Sklearn CountVectorizer
vectorizer = CountVectorizer(ngram_range=(2,2))
X = vectorizer.fit_transform([cor])
n_gram_counts_sk = Counter(dict(zip(vectorizer.get_feature_names_out(), X.toarray()[0])))

# Compare the results
print("Our code generated {} unique N-grams.".format(len(tokens)))
print("Sklearn CountVectorizer generated {} unique N-grams.".format(len(n_gram_counts_sk)))
# Out:
# Our code generated 101 unique N-grams.
# Sklearn CountVectorizer generated 97 unique N-grams.
